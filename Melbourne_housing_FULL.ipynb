# %%
import pandas as pd

# %%
df=pd.read_csv("Melbourne_housing_FULL.csv")
df
# Out:
#            Suburb             Address  Rooms Type      Price Method  \
# 0      Abbotsford       68 Studley St      2    h        NaN     SS
# 1      Abbotsford        85 Turner St      2    h  1480000.0      S
# 2      Abbotsford     25 Bloomburg St      2    h  1035000.0      S
# 3      Abbotsford  18/659 Victoria St      3    u        NaN     VB
# 4      Abbotsford        5 Charles St      3    h  1465000.0     SP
# ...           ...                 ...    ...  ...        ...    ...
# 34852  Yarraville         13 Burns St      4    h  1480000.0     PI
# 34853  Yarraville       29A Murray St      2    h   888000.0     SP
# 34854  Yarraville      147A Severn St      2    t   705000.0      S
# 34855  Yarraville    12/37 Stephen St      3    h  1140000.0     SP
# 34856  Yarraville    3 Tarrengower St      2    h  1020000.0     PI
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 0             Jellis   3/09/2016       2.5    3067.0  ...       1.0  1.0
# 1             Biggin   3/12/2016       2.5    3067.0  ...       1.0  1.0
# 2             Biggin   4/02/2016       2.5    3067.0  ...       1.0  0.0
# 3             Rounds   4/02/2016       2.5    3067.0  ...       2.0  1.0
# 4             Biggin   4/03/2017       2.5    3067.0  ...       2.0  0.0
# ...              ...         ...       ...       ...  ...       ...  ...
# 34852            Jas  24/02/2018       6.3    3013.0  ...       1.0  3.0
# 34853        Sweeney  24/02/2018       6.3    3013.0  ...       2.0  1.0
# 34854            Jas  24/02/2018       6.3    3013.0  ...       1.0  2.0
# 34855  hockingstuart  24/02/2018       6.3    3013.0  ...       NaN  NaN
# 34856             RW  24/02/2018       6.3    3013.0  ...       1.0  0.0
#
#        Landsize  BuildingArea  YearBuilt               CouncilArea Lattitude  \
# 0         126.0           NaN        NaN        Yarra City Council -37.80140
# 1         202.0           NaN        NaN        Yarra City Council -37.79960
# 2         156.0          79.0     1900.0        Yarra City Council -37.80790
# 3           0.0           NaN        NaN        Yarra City Council -37.81140
# 4         134.0         150.0     1900.0        Yarra City Council -37.80930
# ...         ...           ...        ...                       ...       ...
# 34852     593.0           NaN        NaN  Maribyrnong City Council -37.81053
# 34853      98.0         104.0     2018.0  Maribyrnong City Council -37.81551
# 34854     220.0         120.0     2000.0  Maribyrnong City Council -37.82286
# 34855       NaN           NaN        NaN  Maribyrnong City Council       NaN
# 34856     250.0         103.0     1930.0  Maribyrnong City Council -37.81810
#
#        Longtitude             Regionname Propertycount
# 0       144.99580  Northern Metropolitan        4019.0
# 1       144.99840  Northern Metropolitan        4019.0
# 2       144.99340  Northern Metropolitan        4019.0
# 3       145.01160  Northern Metropolitan        4019.0
# 4       144.99440  Northern Metropolitan        4019.0
# ...           ...                    ...           ...
# 34852   144.88467   Western Metropolitan        6543.0
# 34853   144.88826   Western Metropolitan        6543.0
# 34854   144.87856   Western Metropolitan        6543.0
# 34855         NaN   Western Metropolitan        6543.0
# 34856   144.89351   Western Metropolitan        6543.0
#
# [34857 rows x 21 columns]

# %%
df.isna().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# YearBuilt        19306
# CouncilArea          3
# Lattitude         7976
# Longtitude        7976
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
df.nunique()
# Out:
# Suburb             351
# Address          34009
# Rooms               12
# Type                 3
# Price             2871
# Method               9
# SellerG            388
# Date                78
# Distance           215
# Postcode           211
# Bedroom2            15
# Bathroom            11
# Car                 15
# Landsize          1684
# BuildingArea       740
# YearBuilt          160
# CouncilArea         33
# Lattitude        13402
# Longtitude       14524
# Regionname           8
# Propertycount      342
# dtype: int64

# %%
col=['Suburb','Rooms','Price','Type','Method','SellerG','Regionname','Propertycount','Distance','CouncilArea','Bedroom2','Landsize','BuildingArea']

# %%
df=df[col]
df
# Out:
#            Suburb  Rooms      Price Type Method        SellerG  \
# 0      Abbotsford      2        NaN    h     SS         Jellis
# 1      Abbotsford      2  1480000.0    h      S         Biggin
# 2      Abbotsford      2  1035000.0    h      S         Biggin
# 3      Abbotsford      3        NaN    u     VB         Rounds
# 4      Abbotsford      3  1465000.0    h     SP         Biggin
# ...           ...    ...        ...  ...    ...            ...
# 34852  Yarraville      4  1480000.0    h     PI            Jas
# 34853  Yarraville      2   888000.0    h     SP        Sweeney
# 34854  Yarraville      2   705000.0    t      S            Jas
# 34855  Yarraville      3  1140000.0    h     SP  hockingstuart
# 34856  Yarraville      2  1020000.0    h     PI             RW
#
#                   Regionname  Propertycount  Distance  \
# 0      Northern Metropolitan         4019.0       2.5
# 1      Northern Metropolitan         4019.0       2.5
# 2      Northern Metropolitan         4019.0       2.5
# 3      Northern Metropolitan         4019.0       2.5
# 4      Northern Metropolitan         4019.0       2.5
# ...                      ...            ...       ...
# 34852   Western Metropolitan         6543.0       6.3
# 34853   Western Metropolitan         6543.0       6.3
# 34854   Western Metropolitan         6543.0       6.3
# 34855   Western Metropolitan         6543.0       6.3
# 34856   Western Metropolitan         6543.0       6.3
#
#                     CouncilArea  Bedroom2  Landsize  BuildingArea
# 0            Yarra City Council       2.0     126.0           NaN
# 1            Yarra City Council       2.0     202.0           NaN
# 2            Yarra City Council       2.0     156.0          79.0
# 3            Yarra City Council       3.0       0.0           NaN
# 4            Yarra City Council       3.0     134.0         150.0
# ...                         ...       ...       ...           ...
# 34852  Maribyrnong City Council       4.0     593.0           NaN
# 34853  Maribyrnong City Council       2.0      98.0         104.0
# 34854  Maribyrnong City Council       2.0     220.0         120.0
# 34855  Maribyrnong City Council       NaN       NaN           NaN
# 34856  Maribyrnong City Council       2.0     250.0         103.0
#
# [34857 rows x 13 columns]

# %%
df.dropna(inplace=True)
df
# Out:
# C:\Users\santh\AppData\Local\Temp\ipykernel_8032\955798070.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)
#            Suburb  Rooms      Price Type Method  SellerG  \
# 2      Abbotsford      2  1035000.0    h      S   Biggin
# 4      Abbotsford      3  1465000.0    h     SP   Biggin
# 6      Abbotsford      4  1600000.0    h     VB   Nelson
# 11     Abbotsford      3  1876000.0    h      S   Nelson
# 14     Abbotsford      2  1636000.0    h      S   Nelson
# ...           ...    ...        ...  ...    ...      ...
# 34847     Wollert      3   500000.0    h     PI      Ray
# 34849     Wollert      3   570000.0    h     SP       RW
# 34853  Yarraville      2   888000.0    h     SP  Sweeney
# 34854  Yarraville      2   705000.0    t      S      Jas
# 34856  Yarraville      2  1020000.0    h     PI       RW
#
#                   Regionname  Propertycount  Distance  \
# 2      Northern Metropolitan         4019.0       2.5
# 4      Northern Metropolitan         4019.0       2.5
# 6      Northern Metropolitan         4019.0       2.5
# 11     Northern Metropolitan         4019.0       2.5
# 14     Northern Metropolitan         4019.0       2.5
# ...                      ...            ...       ...
# 34847  Northern Metropolitan         2940.0      25.5
# 34849  Northern Metropolitan         2940.0      25.5
# 34853   Western Metropolitan         6543.0       6.3
# 34854   Western Metropolitan         6543.0       6.3
# 34856   Western Metropolitan         6543.0       6.3
#
#                     CouncilArea  Bedroom2  Landsize  BuildingArea
# 2            Yarra City Council       2.0     156.0          79.0
# 4            Yarra City Council       3.0     134.0         150.0
# 6            Yarra City Council       3.0     120.0         142.0
# 11           Yarra City Council       4.0     245.0         210.0
# 14           Yarra City Council       2.0     256.0         107.0
# ...                         ...       ...       ...           ...
# 34847   Whittlesea City Council       3.0     383.0         118.0
# 34849   Whittlesea City Council       3.0     404.0         158.0
# 34853  Maribyrnong City Council       2.0      98.0         104.0
# 34854  Maribyrnong City Council       2.0     220.0         120.0
# 34856  Maribyrnong City Council       2.0     250.0         103.0
#
# [9382 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9382 entries, 2 to 34856
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         9382 non-null   object
#  1   Rooms          9382 non-null   int64
#  2   Price          9382 non-null   float64
#  3   Type           9382 non-null   object
#  4   Method         9382 non-null   object
#  5   SellerG        9382 non-null   object
#  6   Regionname     9382 non-null   object
#  7   Propertycount  9382 non-null   float64
#  8   Distance       9382 non-null   float64
#  9   CouncilArea    9382 non-null   object
#  10  Bedroom2       9382 non-null   float64
#  11  Landsize       9382 non-null   float64
#  12  BuildingArea   9382 non-null   float64
# dtypes: float64(6), int64(1), object(6)
# memory usage: 1.0+ MB

# %%
df=pd.get_dummies(df,dtype='int')

# %%
x=df.drop(columns=['Price'])

# %%
y=df['Price']

# %%
x
y
# Out:
# 2        1035000.0
# 4        1465000.0
# 6        1600000.0
# 11       1876000.0
# 14       1636000.0
#            ...
# 34847     500000.0
# 34849     570000.0
# 34853     888000.0
# 34854     705000.0
# 34856    1020000.0
# Name: Price, Length: 9382, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=.20)
from sklearn.linear_model import LinearRegression
model=LinearRegression()
